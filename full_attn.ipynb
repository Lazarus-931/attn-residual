# %% [markdown]
# # Kimi Linear + Residual Attention
#
# This, as well, is a small-scale training of a model consisting of Baseline + Full Attention Residuals.

# %% [markdown]
# ### Configurations

# %% [markdown]
# #### Training
#
# Below is the entire end-to-end training
