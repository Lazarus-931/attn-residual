# %% [markdown]
# # Kimi Linear + Block Attention Residuals
#
# This is the baseline + block attention residuals.

# %% [markdown]
# ### Configurations

# %% [markdown]
# #### Training
#
# This is an entire end-to-end training
